# %% [markdown]
# <a href="https://colab.research.google.com/github/SorosPhotchara/lab5/blob/main/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# รหัสนักศึกษา : 67015091 ชื่อ : นายพชร โสรส

# %% [markdown]
# Exercise 5.1 ให้เขียน function ชื่อ day_of_year(day, month ,year) โดยมีการคืนค่า คือ day_of_years เป็นวันที่ลำดับที่เท่าใดของปีคริสตศักราช year
# ปีที่เป็น Leap Year เดือนกุมภาพันธ์จะมี 29 วัน
# ให้สร้างฟังก์ชัน is_leap เพื่อตรวจสอบ leap year แยกออกมา และให้ฟังก์ชัน day_of_year เรียกใช้ is_leap อีกที

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
  if year%4 == 0 and year%100 !=0 or year%400 == 0:
    return True
  else :
    return False


def day_of_year(day, month, year):
  sumday = 0
  for i in range(month):
    sumday = sum(days_in_month[:month-1])
    sumday = sumday+day
  if is_leap(year) and month > 2 :
    sumday = sumday + 1
  return sumday





# Testcases
print("Normal year (2023):")
print(f"1 Jan 2023: {day_of_year(1, 1, 2023)}")  # ควรได้ 1
print(f"1 Feb 2023: {day_of_year(1, 2, 2023)}")  # ควรได้ 32
print(f"1 Mar 2023: {day_of_year(1, 3, 2023)}")  # ควรได้ 60
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365

print("\nLeap year (2024):")
print(f"1 Jan 2024: {day_of_year(1, 1, 2024)}")  # ควรได้ 1
print(f"29 Feb 2024: {day_of_year(29, 2, 2024)}")  # ควรได้ 60
print(f"1 Mar 2024: {day_of_year(1, 3, 2024)}")  # ควรได้ 61
print(f"31 Dec 2024: {day_of_year(31, 12, 2024)}")  # ควรได้ 366

print("\nCentury year, not a leap year (1900):")
print(f"1 Mar 1900: {day_of_year(1, 3, 1900)}")  # ควรได้ 60

print("\nCentury year, leap year (2000):")
print(f"1 Mar 2000: {day_of_year(1, 3, 2000)}")  # ควรได้ 61

print("\nMid-year dates:")
print(f"15 Jun 2023: {day_of_year(15, 6, 2023)}")  # ควรได้ 166
print(f"15 Jun 2024: {day_of_year(15, 6, 2024)}")  # ควรได้ 167 (Leap year)

print("\nLast day of each quarter:")
print(f"31 Mar 2023: {day_of_year(31, 3, 2023)}")  # ควรได้ 90
print(f"30 Jun 2023: {day_of_year(30, 6, 2023)}")  # ควรได้ 181
print(f"30 Sep 2023: {day_of_year(30, 9, 2023)}")  # ควรได้ 273
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365

# %% [markdown]
# Exercise 5.2 ให้เขียนฟังก์ชัน เพิ่มเติมเป็น date_diff
# รับข้อมูลในรูปแบบ “dd-mm-yyyy” เช่น date_diff(“1-1-2018”, “1-1-2020”) จะได้ 731 วัน date_diff(“25-12-1999”, “9-3-2000”) จะได้ 76 วัน
# ให้เขียนฟังก์ชัน day_in_year โดยจะส่งค่าจำนวนวันของปี (365 หรือ 366) โดยรับข้อมูลเป็น ปี
# ส่งคืนข้อมูลเป็นจำนวนวันตั้งแต่วันที่แรก จนถึงวันที่สอง โดยรวมทั้ง 2 วันนั้นเข้าไปด้วย
# ให้สมมติว่าวันแรก จะต้องมาก่อนวันที่สองเสมอ ดังนั้นไม่ต้องตรวจสอบ

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
  if year%4 == 0 and year%100 !=0 or year%400 == 0:
    return True
  else :
    return False

def day_of_year(day, month, year):
  sumday = 0
  for i in range(month):
    sumday = sum(days_in_month[:month-1])
    sumday = sumday+day
  if is_leap(year) and month > 2 :
    sumday = sumday + 1
  return sumday

def day_in_year(year):
    return 366 if is_leap(year) else 365

def date_diff(date1, date2):
    allsumday = 0
    day1,month1,year1 = date1.split('-')
    day2,month2,year2 = date2.split('-')
    if int(year1) == int(year2) :
      daysum = day_in_year(int(year1))
      day1pass = day_of_year(int(day1), int(month1), int(year1))
      day2pass = day_of_year(int(day2), int(month2), int(year2))
      result = daysum - (daysum - day2pass)
      return result
    else :
      daysum = day_in_year(int(year1)) + day_in_year(int(year2))
      for i in range(int(year1)+1,int(year2)):
        if is_leap(int(year1)+1):
          daysum = daysum + 366
        else:
          daysum = daysum + 365
      day1pass = day_of_year(int(day1), int(month1), int(year1))
      day2pass = day_of_year(int(day2), int(month2), int(year2))
      result = daysum - day1pass - (day_in_year(int(year2)) - day2pass)
      return result+1


# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 731
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 76
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 367 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 366 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 367 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 365 (ทั้งปี 2023)
# Out:
# 731
# 76
# 367
# 366
# 366
# 365

# %% [markdown]
# Exercise 5.3 จากโปรแกรม 5.2 ให้เขียนฟังก์ชัน date_diff  เพิ่มเติม โดยให้มีการตรวจสอบ
# วันที่ต้องเป็นวันที่ถูกต้องของเดือนนั้นๆ
# เดือนต้องอยู่ระหว่าง 1-12
# เดือนกุมภาพันธ์ของปีที่มี Leap Year เท่านั้นที่จะมี 29 วันได้
# หากข้อมูล Input ผิดพลาด ให้ Return -1

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def day_of_year(day, month, year):
    sumday = sum(days_in_month[:month-1]) + day
    if is_leap(year) and month > 2:
        sumday += 1
    return sumday

def day_in_year(year):
    return 366 if is_leap(year) else 365

def is_valid_date(day, month, year):
    if month < 1 or month > 12:
        return False
    if day < 1 or day > days_in_month[month-1]:
        return False
    if month == 2 and is_leap(year) and day > 29:
        return False
    if month == 2 and not is_leap(year) and day > 28:
        return False
    return True

def date_diff(date1, date2):
    try:
        day1, month1, year1 = map(int, date1.split('-'))
        day2, month2, year2 = map(int, date2.split('-'))
    except ValueError:
        return -1

    if not is_valid_date(day1, month1, year1) or not is_valid_date(day2, month2, year2):
        return -1

    if year1 == year2:
        day1pass = day_of_year(day1, month1, year1)
        day2pass = day_of_year(day2, month2, year2)
        return day2pass - day1pass
    else:
        if year1 > year2 or (year1 == year2 and day_of_year(day1, month1, year1) > day_of_year(day2, month2, year2)):
            day1, month1, year1, day2, month2, year2 = day2, month2, year2, day1, month1, year1

        daysum = day_in_year(year1) - day_of_year(day1, month1, year1) + 1
        daysum += day_of_year(day2, month2, year2)

        for year in range(year1 + 1, year2):
            daysum += day_in_year(year)

        return daysum

# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 730
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 75
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 366 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 365 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 366 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 364 (ทั้งปี 2023)

# ทดสอบกรณีข้อมูลไม่ถูกต้อง
print()
print(date_diff("31-4-2023", "1-5-2023"))  # ควรได้ -1 (เดือนเมษายนมี 30 วัน)
print(date_diff("29-2-2023", "1-3-2023"))  # ควรได้ -1 (ปี 2023 ไม่ใช่ leap year)
print(date_diff("1-13-2023", "1-1-2024"))  # ควรได้ -1 (เดือนไม่ถูกต้อง)
print(date_diff("abc", "1-1-2024"))  # ควรได้ -1 (รูปแบบวันที่ไม่ถูกต้อง)
# Out:
# 731
# 76
# 367
# 366
# 366
# 364
#
# -1
# -1
# -1
# -1

# %% [markdown]
# 1.	ปลาหมอคางดำเพศเมีย 1 ตัว เมื่ออายุครบ 2 เดือน จะสามารถสืบพันธ์ได้ โดยระยะเวลาตั้งท้องจนถึง
# วางไข่ของตัวเมียจะใช้เวลา 21 วัน และฟักในปากเพศผู้อีก 7 วัน (สามารถรวมเป็น 1 เดือนได้) โดยออกไข่ครั้งละ 300 ฟอง กำหนดให้ไข่ฟักเป็นเพศผู้และเพศเมียอย่างละครึ่ง และเมื่อวางไข่แล้วจะสามารถสืบพันธ์ต่อได้ทันที กำหนดให้ปลามีอายุ 5 ปี และปลาทั้งหมดจะตาย p% ทุก 1 เดือน จงหาว่าปลาหมอคางดำหลุดจากฟาร์ม n ตัวเป็นเพศผู้และเพศเมียอย่างละครึ่ง จงเขียนโปรแกรมรับค่า n และ p ให้แสดงผลจำนวนปลาทุก 3 เดือน เป็นเวลา 10 ปี ให้เขียนเป็นฟังก์ชัน ชื่อ simulate_fish_population()

# %%
import math
def simulate_fish_population(n, p ,month=3):
  round = month / 3
  monthcount = 0
  egg_fish = 0
  baby_fish = 0
  big_fish = 0
  for i in range(int(round)):
    egg_fish += (n/2) * 300
    monthcount +=1
    baby_fish += egg_fish - (egg_fish * 10/100)
    egg_fish -= (n/2) * 300
    egg_fish += (n/2) * 300
    monthcount +=1
    big_fish = baby_fish - (baby_fish * 10/100)
    print(f'เดือนที่ : {monthcount}, ไข่ปลา : {int(egg_fish)} ใบ + ลูกปลา : {int(baby_fish)} ตัว + ปลาเต็มวัย : {int(big_fish)} + {int(n)} ตัว = {int(baby_fish+big_fish+n)} ตัว')
    big_fish += n
    monthcount +=1
    n = big_fish
  return egg_fish ,baby_fish ,big_fish

month = 10 * 12
n = 2  # Initial number of fish
p = 10  # Monthly mortality rate

simulate_fish_population(n, p, month)

# ถ้าเริ่มต้นด้วยปลา 2 ตัว ตายเดือนละ 10%
# เดือนที่ 1 ไข่ 300 ไบ
# เดือนที่ 2 ไข่ 300 ใบ + ลูกปลา 270 ตัว
# เดือนที่ 3 ไข่ 300 ใบ + ลูกปลา 270 ตัว + ปลาโตเต็มวัย 243 ตัว + 2 = 515 ตัว
# Out:
# เดือนที่ : 2, ไข่ปลา : 300 ใบ + ลูกปลา : 270 ตัว + ปลาเต็มวัย : 243 + 2 ตัว = 515 ตัว
# เดือนที่ : 5, ไข่ปลา : 37050 ใบ + ลูกปลา : 33615 ตัว + ปลาเต็มวัย : 30253 + 245 ตัว = 64113 ตัว
# เดือนที่ : 8, ไข่ปลา : 4611825 ใบ + ลูกปลา : 4184257 ตัว + ปลาเต็มวัย : 3765831 + 30498 ตัว = 7980587 ตัว
# เดือนที่ : 11, ไข่ปลา : 574061362 ใบ + ลูกปลา : 520839483 ตัว + ปลาเต็มวัย : 468755535 + 3796330 ตัว = 993391349 ตัว
# เดือนที่ : 14, ไข่ปลา : 71456841206 ใบ + ลูกปลา : 64831996569 ตัว + ปลาเต็มวัย : 58348796912 + 472551865 ตัว = 123653345347 ตัว
# เดือนที่ : 17, ไข่ปลา : 8894659157915 ใบ + ลูกปลา : 8070025238693 ตัว + ปลาเต็มวัย : 7263022714824 + 58821348778 ตัว = 15391869302295 ตัว
# เดือนที่ : 20, ไข่ปลา : 1107171268698239 ใบ + ลูกปลา : 1004524167067108 ตัว + ปลาเต็มวัย : 904071750360397 + 7321844063602 ตัว = 1915917761491108 ตัว
# เดือนที่ : 23, ไข่ปลา : 137816210432298240 ใบ + ลูกปลา : 125039113556135520 ตัว + ปลาเต็มวัย : 112535202200521968 + 911393594424000 ตัว = 238485709351081472 ตัว
# เดือนที่ : 26, ไข่ปลา : 17154805579674193920 ใบ + ลูกปลา : 15564364135262910464 ตัว + ปลาเต็มวัย : 14007927721736620032 + 113446595794945968 ตัว = 29685738452794474496 ตัว
# เดือนที่ : 29, ไข่ปลา : 2135360953209409241088 ใบ + ลูกปลา : 1937389222023731085312 ตัว + ปลาเต็มวัย : 1743650299821358055424 + 14121374317531566080 ตัว = 3695160896162620768256 ตัว
# เดือนที่ : 32, ไข่ปลา : 265801112074042847789056 ใบ + ลูกปลา : 241158390088662272442368 ตัว + ปลาเต็มวัย : 217042551079796041842688 + 1757771674138889682944 ตัว = 459958712842597200560128 ตัว
# เดือนที่ : 35, ไข่ปลา : 33085849525164283676065792 ใบ + ลูกปลา : 30018422962736515386441728 ตัว + ปลาเต็มวัย : 27016580666462865136287744 + 218800322753934928117760 ตัว = 57253803951953319376715776 ตัว
# เดือนที่ : 38, ไข่ปลา : 4118392997907684628814102528 ใบ + ลูกปลา : 3736572121079652551611121664 ตัว + ปลาเต็มวัย : 3362914908971687461376753664 + 27235380989216799695306752 ตัว = 7126722411040557568597426176 ตัว
# เดือนที่ : 41, ไข่ปลา : 512640936492043337670957465600 ใบ + ลูกปลา : 465113414963918611925251915776 ตัว + ปลาเต็มวัย : 418602073467526743695852306432 + 3390150289960904467230490624 ตัว = 887105638721406305168311451648 ตัว
# เดือนที่ : 44, ไข่ปลา : 63811474500115185291074633465856 ใบ + ลูกปลา : 57895440465067590538958244675584 ตัว + ปลาเต็มวัย : 52105896418560833286502271156224 + 421992223757487622874315358208 ตัว = 110423329107385917077834365403136 ตัว
# เดือนที่ : 47, ไข่ปลา : 7942994770847863436539353108578304 ใบ + ลูกปลา : 7206590734228144946434594280833024 ตัว + ปลาเต็มวัย : 6485931660805330336498984392065024 + 52527888642318317531676865986560 ตัว = 13745050283675791826047002354909184 ตัว
# เดือนที่ : 50, ไข่ปลา : 988711927187995169773718660649582592 ใบ + ลูกปลา : 897047325203423652705256109324107776 ตัว + ปลาเต็มวัย : 807342592683081316949521016326979584 + 6538459549447649185455417287770112 ตัว = 1710928377435952716838560434520850432 ตัว
# เดือนที่ : 53, ไข่ปลา : 123070869762067316715689599303646445568 ใบ + ลูกปลา : 111660830111064009228092124805440995328 ตัว + ปลาเต็มวัย : 100494747099957602638443132881322639360 + 813881052232528916559351735520329728 ตัว = 212969458263254114662505001049558876160 ตัว
# เดือนที่ : 56, ไข่ปลา : 15319365092590585455281930607786773708800 ใบ + ลูกปลา : 13899089413442592751260025025235880247296 ตัว + ปลาเต็มวัย : 12509180472098334201489514291489797046272 + 101308628152190124323878807722698735616 ตัว = 26509578513693115225905756839547452260352 ตัว
# เดือนที่ : 59, ไข่ปลา : 1906892730130169457147431023211000904024064 ใบ + ลูกปลา : 1730102546530595138517441222970605255524352 ตัว + ปลาเต็มวัย : 1557092291877535531820194154270024112537600 + 12610489100250524892497371043569921425408 ตัว = 3299805327508381180723022912908649193013248 ตัว
# เดือนที่ : 62, ไข่ปลา : 237362309876798047315363780950171268847501312 ใบ + ลูกปลา : 215356181435648845830852101397365547807539200 ตัว + ปลาเต็มวัย : 193820563292083941440726262691544594640797696 + 1569702780977786042205581689938043937488896 ตัว = 410746447508710516678027148472700609750892544 ตัว
# เดือนที่ : 65, ไข่ปลา : 29545902220836053230010965412449842189127647232 ใบ + ลูกปลา : 26806668180188097759038384903759310956030590976 ตัว + ปลาเต็มวัย : 24126001362169287476074306322091619261746249728 + 195390266073061710461256304207503858715328512 ตัว = 51128059808430444647957234616392643863717609472 ตัว
# เดือนที่ : 68, ไข่ปลา : 3677754646457187822896513574835734267027913703424 ใบ + ลูกปลา : 3336785849991657009572599619067812959216107257856 ตัว + ปลาเต็มวัย : 3003107264992491178807918193790340950032088301568 + 24321391628242346888918849712633332907687018496 ตัว = 6364214506612390033279798972191944249461413249024 ตัว
# เดือนที่ : 71, ไข่ปลา : 457792053139567169936609138485007384721553623089152 ใบ + ลูกปลา : 415349633675602133058241844735557406169323033067520 ตัว + ปลาเต็มวัย : 373814670308041919752417660262001665552390729760768 + 3027428656620733672744306669977584856557347143680 ตัว = 792191732640264758574808197042838153226853340413952 ตัว
# เดือนที่ : 74, ไข่ปลา : 56984106897838965151259048812439222267748163101130752 ใบ + ลูกปลา : 51701045841730673444262727293074051666054378638278656 ตัว + ปลาเต็มวัย : 46530941257557608226601247819632043145540237223002112 + 376842098964662625516566352307280747057530307346432 ตัว = 98608829198252944877917789620914069954067735041277952 ตัว
# เดือนที่ : 77, ไข่ปลา : 7093151610376178872028896960759591239955058973101522944 ใบ + ลูกปลา : 6435537495180291007480243255681894793921670741172944896 ตัว + ปลาเต็มวัย : 5791983745662261770619272161738319929179660694348365824 + 46907783356522271433655062327840018288013356402999296 ตัว = 12274429024199075347280241535569210271842126294721495040 ตัว
# เดือนที่ : 80, ไข่ปลา : 882926880963193930565609247541642098086907191808774635520 ใบ + ลูกปลา : 801069730362054763182314117222974798104213516469573517312 ตัว + ปลาเต็มวัย : 720962757325849304286539891852726647618572065329148592128 + 5838891529018784339799998279887315477920455553548550144 ตัว = 1527871379216922808252511041475465437888756286085939593216 ตัว
# เดือนที่ : 83, ไข่ปลา : 109903174209193384313985392714488868500475216158123205066752 ใบ + ลูกปลา : 99713926518636101447202198132457225597471783482080949698560 ตัว + ปลาเต็มวัย : 89742533866772496877668277951867288421654173295963231223808 + 726801648854868045070196924252490639784542769616366075904 ตัว = 190183262034263471074004113323630323576601072684424302166016 ตัว
# เดือนที่ : 86, ไข่ปลา : 13680303501553296419853791230083154279512295150486583429300224 ใบ + ลูกปลา : 12411987077916603434604169748619812301397922407864207534981120 ตัว + ปลาเต็มวัย : 11170788370124942377519906420777890542115145442330218590109696 + 90469335515627369626801915191173097979129289202343352467456 ตัว = 23673244783557172278570697544098638709295607097138128485351424 ตัว
# เดือนที่ : 89, ไข่ปลา : 1702868959347638914173362272567722851354502766238582548065157120 ใบ + ลูกปลา : 1544994050490791710398244084711203360959322609542801547375673344 ตัว + ปลาเต็มวัย : 1390494645441712484552108276331223592225209121727908155540635648 + 11261257705640570271214220501438707466183654138769057333116928 ตัว = 2946749953638144662459732706714754224454125585045828940691668992 ตัว
# เดือนที่ : 92, ไข่ปลา : 211966254431450593050034344887597968454132402642886093878941712384 ใบ + ลูกปลา : 192314623038796334626351928734965186697800810282816234379399921664 ตัว + ปลาเต็มวัย : 173083160734916687133301017484800653272646335178217622244507516928 + 1401755903147353134749193288366415638955407065038404850307563520 ตัว = 366799539676860362106262812862731721327160266258595839484805251072 ตัว
# เดือนที่ : 95, ไข่ปลา : 26384703750141060935187635444375398037740698839510358515338644029440 ใบ + ลูกปลา : 23938547998165750287702228331483849152824051474342062947377193418752 ตัว + ปลาเต็มวัย : 21544693198349174959616470172966546589426992586613094227104489275392 + 174484916638064050863937081422213225888316779436307919600326017024 ตัว = 45657726113152990724608233620833857134935757571483692278272170655744 ตัว
# เดือนที่ : 98, ไข่ปลา : 3284261420998227180347884787413281772015134286663811994745882493845504 ใบ + ลูกปลา : 2979773826896569966563428499550187137216199534949478144428913931059200 ตัว + ปลาเต็มวัย : 2681796444206912969907085649595168423494579581454530329986022537953280 + 21719178114987240436906005289350007982111706097141629330894977236992 ตัว = 5683289449218469868612418769304720391134797469997544805444797100720128 ตัว
# เดือนที่ : 101, ไข่ปลา : 408811604769283245436350553867203724564265908275521258950019484890431488 ใบ + ลูกปลา : 370910218119251515072708472661077501306938545957803712375524580833361920 ตัว + ปลาเต็มวัย : 333819196307326363565437625394969751176244691362023341137972122750025728 + 2703515622321900285172875486226747843505354722625362565700663715561472 ตัว = 707432930048899786968920563088190506708010484581575630077577758762860544 ตัว
# เดือนที่ : 104, ไข่ปลา : 50887218394216523049071017963765285185382959325643431398264957976809832448 ใบ + ลูกปลา : 46169406772914119042221985254375942702309522545107853718356821472144523264 ตัว + ปลาเต็มวัย : 41552466095622703371738745496929890130604916365997218685107872646509363200 + 336522711929648271896212090427113005401071938623771917702053177929498624 ตัว = 88058395580466471274335230534234267447920769275447570830762570215086620672 ตัว
# เดือนที่ : 107, ไข่ปลา : 6334235539527069458299685576129406218399700740199263655896814380842676649984 ใบ + ลูกปลา : 5746981392347276834890035230299298287541617500652837025741806164865271726080 ตัว + ปลาเต็มวัย : 5172283253112549151401031707269368458787455750587553323167625548378744553472 + 41888988807552352232113245279858324745611246730339717112405748742942097408 ตัว = 10961153634267377911680262176554233130241003719849413771061667238432611500032 ตัว
# เดือนที่ : 110, ไข่ปลา : 788460071827542361942284334622077089293218159424437881013419968713559719804928 ใบ + ลูกปลา : 715361046037135346018726778473710979574372310573723321156274396852761216942080 ตัว + ปลาเต็มวัย : 643824941433421811416854100626339881616935079516350989040646957167485095247872 + 5214172241920101880259249075750072613680432389777878006421357964963757424640 ตัว = 1364400159712477395102104868060479217100784625308092101329495686631204652580864 ตัว
# เดือนที่ : 113, ไข่ปลา : 98144327123128835429128156044659821496960291902597242869478780743755012224581632 ใบ + ลูกปลา : 89045255456853085874692807428672565548989059413097075292930087918528884956463104 ตัว + ปลาเต็มวัย : 80140729911167773338012589114910807822164115334146155805071001606084324424155136 + 649039113675341946239343257011390602840838404899962218752229687679701976350720 ตัว = 169835024481696176990596554145381019822884144341057651382820292719088668424273920 ตัว
# เดือนที่ : 116, ไข่ปลา : 12216609680849596346713336065888242436589233485067463296023991620870283314746884096 ใบ + ลูกปลา : 11083993968221490400829565069217984604060007684987039067388943714845445799159005184 ตัว + ปลาเต็มวัย : 9975594571399341192246941892604687426985162622615643450417896702482323212345540608 + 80789769024843117443976663856005128753402005845568655813664054937837597045555200 ตัว = 21140378308645675934775874272655972523095644136117026880775988503649024939915214848 ตัว
# เดือนที่ : 119, ไข่ปลา : 1520674260744477195594116379104233188455618018548977992286031591937755284978515574784 ใบ + ลูกปลา : 1379690828638250968794529639638708836247480044493284916068067513431125294376388919296 ตัว + ปลาเต็มวัย : 1241721745774425915050991343115861624089956179275365502280691838152928734704526426112 + 10056384340424183848949642506523000752347193512403070711065518380017799071780569088 ตัว = 2631468958753100730695137285878096027752094829535670068595519588206915814357567799296 ตัว
# (1.5206742607444772e+84, 1.379690828638251e+84, 1.2517781301148502e+84)

# %% [markdown]
# 2.	ให้เขียน function find_mismatch ซึ่งรับ string มา 2 ค่า โดยจะส่งค่ากลับดังนี้
# - 0 เมื่อ string ทั้ง 2 ตัว เหมือนกัน โดยไม่สนใจ case
# - 1 เมื่อ string 1 จะเหมือน string 2 โดยการลบและ/หรือเพิ่มตัวอักษรเพียง 1 ตัว
# - 2 เมื่อ string ไม่เข้าเกณฑ์ 0 หรือ 1
#
#
# | String  1| 	String2	|ผลลัพธ์|
# |----------|----------|------|
# |Python|	Java	|2|
# |book	 |  boot	|1|
# |fan	 |  fun	  |1|
# |sin	 | sink	  |1 เพราะเพิ่ม k ใน str2 แล้วจะเหมือนกัน
# |Dog	 | dog	  |0
# |poke	 | spoke	|1 เพิ่ม s ใน str2 แล้วเหมือนกัน
# |poker |	poke	|1 ตัด r ใน str1 ออกแล้วเหมือนกัน

# %%
# str1 = 'Dog'
# str2 = 'dog'

def Convert(str1, str2):
    str1 = list(str1.lower())
    str2 = list(str2.lower())
    return str1, str2

def find_mismatch(str1, str2):
    x = 0
    str1, str2 = Convert(str1, str2)
    i = 0
    while i < len(str1):
        j = 0
        while j < len(str2):
            # print(f'{str1} - {str2}')
            # print(f'{str1[i]} - {str2[j]}')
            if str1[i] == str2[j]:
                str1.pop(i)
                str2.pop(j)
                if i > 0:
                    i -= 1
                break
            else:
                j += 1
        else:
            i += 1
    if len(str1)>len(str2):
      x =  len(str1) - len(str2)
    elif len(str1)<len(str2):
      x =  len(str2) - len(str1)
    else :
      if len(str1) == 0 and len(str2) == 0 :
        return 0#,str1,str2,x

    if x >= 0 and x < 2:
      return 1#,str1,str2,x
    else :
      return 2#,str1,str2,x



print(find_mismatch('Python', 'Java'))
print(find_mismatch('book', 'boot'))
print(find_mismatch('fan', 'fun'))
print(find_mismatch('sin', 'sink'))
print(find_mismatch('Dog', 'dog'))
print(find_mismatch('spoke', 'poke'))
print(find_mismatch('poker', 'poke'))
# Out:
# 2
# 1
# 1
# 1
# 0
# 1
# 1

# %% [markdown]
# 3.	จากข้อ 1 ให้เขียนฟังก์ชันชื่อ spelling_correction โดยรับ 2 argument ตัวแรกเป็นประโยค (string) และตัวที่ 2 เป็น list ของคำ (correct_spells) โดยฟังก์ชันนี้มีหน้าที่ตรวจสอบแต่ละ word ใน input string กับคำที่อยู่ใน correct_spells โดยค่าที่คืนกลับมาจะมีดังนี้ (พยายามเรียกใช้ฟังก์ชันในข้อ 1)
# -	ถ้าคำที่อยู่ในประโยค ตรงกับคำที่อยู่ใน correct_spells ทุกอย่าง ก็จะ copy ไปที่ output string
# -	ถ้าคำที่อยู่ในประโยค ต่างจากคำที่อยู่ใน correct_spells โดยต่างกัน 1 ตัวอักษร โดยการเปลี่ยน การเพิ่ม หรือการลบ 1 ตัวอักษร คำที่อยู่ในประโยคจะถูกเปลี่ยนโดยคำที่อยู่ใน correct_spells และนำไปใส่ output string
# -	ถ้าคำที่ไม่พบในเงื่อนไขข้างต้นให้นำคำนั้นไปใส่ output string ได้เลย
# -	คำที่ประกอบด้วย 1 หรือ 2 ตัวอักษรจะไม่ตรวจสอบ ให้นำคำนั้นไปใส่ output string ได้เลย
# -	ถ้ามี 2 คำใน correct_spells ที่ตรงตามเงื่อนไข ให้ใช้คำแรก
# -	ไม่สนใจตัวใหญ่ ตัวเล็ก
# -	Input string จะมีได้เพียงอักษรภาษาอังกฤษเท่านั้น
# -	ในแต่ละคำจะคั่นด้วย 1 space ถ้ามี space มากกว่านั้นให้ตัดออก และตัด space จากหัวท้ายประโยค
#
# |ประโยค	|correct_spells	|output string |
# |-------|---------------|-------------|
# |Thes is the Firs cas	|[‘that’,’first’,’case’,’car’]|	thes is the first car|
# |programming is fan and easy	|[‘programming’,’this’,’fun’,’easy’,book’]	|programming is fun and easy|
# |Thes is vary essy	|[‘this’,’is’,’very’,’easy’]	|this is very easy|
# |Wee ipve Pythen	|[‘we’,’live’,’ln’,’Python’]	|we live python|

# %%
x1 = 'Thes is the Firs cas'
sent1 = ['that','first','case','car']
x2 = 'programming is fan and easy'
sent2 = ['programming','this','fun','easy','book']
x3 = 'Thes is vary essy'
sent3 = ['this','is','very','easy']
x4 = 'Wee ipve Pythen'
sent4 = ['we','live','ln','Python']

def spelling_correction(input_string, correct_spells):
  pass

# %% [markdown]
# 4. ให้เขียนฟังก์ชัน find_word_horizontal ซึ่งจะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตามแถวของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบ จะส่งคืน row index และ column index ของตัวอักษรแรก ถ้าไม่พบจะส่งคืน None
#
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','c','a','t'],
#             ['t',' e','t','k']]
# 	word='cat'
# 	find_word_horizontal(crosswords,word)
# ```
#
# Output
#    [2,1]

# %%
crosswords=[['s','d','o','g'],
            ['c','u','c','m'],
            ['a','c','a','t'],
            ['t',' e','t','k']]
word='cat'

def find_word_horizontal(crosswords, word):
    pass
find_word_horizontal(crosswords,word)

# %% [markdown]
# 5. ให้เขียนฟังก์ชัน find_word_vertical ซึ่งจะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตามคอลัมน์ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบ จะส่งคืน row index และ column index ของตัวอักษรแรก ถ้าไม่พบจะส่งคืน None
#
# ตัวอย่าง
# ```
# 	crosswords=[['s','d','o','g'],
#               ['c','u','c','m'],
#               ['a','c','a','t'],
#               ['t',' e','t','k']]
# 	word='cat'
# 	find_word_vertical(crosswords,word)
# ```
#
# Output
#    [1,0]

# %%
def find_word_vertical(crosswords, word):
    pass

# %% [markdown]
# 6.	ให้เขียนฟังก์ชัน capitalize_word_in_crossword จะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตาม row และ column ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบจะเปลี่ยนเป็นตัวใหญ่และ และส่งคืน list ที่แก้ไขแล้ว แต่ถ้าไม่เจอจะส่ง list เดิมกลับมา ให้ใช้ฟังก์ชันตามข้อ 3 และ 4 ช่วย
#
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','x','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# ```
# จะส่งค่ากลับ
# ```
#  [['s','d','o','g'],
#   ['C','u','c','m'],
#   ['A','x','a','t'],
#   ['T','e','t','k']]
# ```
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','c','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# จะส่งค่ากลับ
# [['s','d','o','g'],
#  ['c','u','c','m'],
#  ['a','C','A','T'],
#  ['t','e','t','k']]
# ```

# %%
def capitalize_word_in_crossword(crosswords, word):
    pass
