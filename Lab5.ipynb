# %% [markdown]
# <a href="https://colab.research.google.com/github/SorosPhotchara/lab5/blob/main/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# รหัสนักศึกษา : 67015091 ชื่อ : นายพชร โสรส

# %% [markdown]
# Exercise 5.1 ให้เขียน function ชื่อ day_of_year(day, month ,year) โดยมีการคืนค่า คือ day_of_years เป็นวันที่ลำดับที่เท่าใดของปีคริสตศักราช year
# ปีที่เป็น Leap Year เดือนกุมภาพันธ์จะมี 29 วัน
# ให้สร้างฟังก์ชัน is_leap เพื่อตรวจสอบ leap year แยกออกมา และให้ฟังก์ชัน day_of_year เรียกใช้ is_leap อีกที

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
  if year%4 == 0 and year%100 !=0 or year%400 == 0:
    return True
  else :
    return False


def day_of_year(day, month, year):
  sumday = 0
  for i in range(month):
    sumday = sum(days_in_month[:month-1])
    sumday = sumday+day
  if is_leap(year) and month > 2 :
    sumday = sumday + 1
  return sumday





# Testcases
print("Normal year (2023):")
print(f"1 Jan 2023: {day_of_year(1, 1, 2023)}")  # ควรได้ 1
print(f"1 Feb 2023: {day_of_year(1, 2, 2023)}")  # ควรได้ 32
print(f"1 Mar 2023: {day_of_year(1, 3, 2023)}")  # ควรได้ 60
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365

print("\nLeap year (2024):")
print(f"1 Jan 2024: {day_of_year(1, 1, 2024)}")  # ควรได้ 1
print(f"29 Feb 2024: {day_of_year(29, 2, 2024)}")  # ควรได้ 60
print(f"1 Mar 2024: {day_of_year(1, 3, 2024)}")  # ควรได้ 61
print(f"31 Dec 2024: {day_of_year(31, 12, 2024)}")  # ควรได้ 366

print("\nCentury year, not a leap year (1900):")
print(f"1 Mar 1900: {day_of_year(1, 3, 1900)}")  # ควรได้ 60

print("\nCentury year, leap year (2000):")
print(f"1 Mar 2000: {day_of_year(1, 3, 2000)}")  # ควรได้ 61

print("\nMid-year dates:")
print(f"15 Jun 2023: {day_of_year(15, 6, 2023)}")  # ควรได้ 166
print(f"15 Jun 2024: {day_of_year(15, 6, 2024)}")  # ควรได้ 167 (Leap year)

print("\nLast day of each quarter:")
print(f"31 Mar 2023: {day_of_year(31, 3, 2023)}")  # ควรได้ 90
print(f"30 Jun 2023: {day_of_year(30, 6, 2023)}")  # ควรได้ 181
print(f"30 Sep 2023: {day_of_year(30, 9, 2023)}")  # ควรได้ 273
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365

# %% [markdown]
# Exercise 5.2 ให้เขียนฟังก์ชัน เพิ่มเติมเป็น date_diff
# รับข้อมูลในรูปแบบ “dd-mm-yyyy” เช่น date_diff(“1-1-2018”, “1-1-2020”) จะได้ 731 วัน date_diff(“25-12-1999”, “9-3-2000”) จะได้ 76 วัน
# ให้เขียนฟังก์ชัน day_in_year โดยจะส่งค่าจำนวนวันของปี (365 หรือ 366) โดยรับข้อมูลเป็น ปี
# ส่งคืนข้อมูลเป็นจำนวนวันตั้งแต่วันที่แรก จนถึงวันที่สอง โดยรวมทั้ง 2 วันนั้นเข้าไปด้วย
# ให้สมมติว่าวันแรก จะต้องมาก่อนวันที่สองเสมอ ดังนั้นไม่ต้องตรวจสอบ

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
  if year%4 == 0 and year%100 !=0 or year%400 == 0:
    return True
  else :
    return False

def day_of_year(day, month, year):
  sumday = 0
  for i in range(month):
    sumday = sum(days_in_month[:month-1])
    sumday = sumday+day
  if is_leap(year) and month > 2 :
    sumday = sumday + 1
  return sumday

def day_in_year(year):
    return 366 if is_leap(year) else 365

def date_diff(date1, date2):
    allsumday = 0
    day1,month1,year1 = date1.split('-')
    day2,month2,year2 = date2.split('-')
    if int(year1) == int(year2) :
      daysum = day_in_year(int(year1))
      day1pass = day_of_year(int(day1), int(month1), int(year1))
      day2pass = day_of_year(int(day2), int(month2), int(year2))
      result = daysum - (daysum - day2pass)
      return result
    else :
      daysum = day_in_year(int(year1)) + day_in_year(int(year2))
      for i in range(int(year1)+1,int(year2)):
        if is_leap(int(year1)+1):
          daysum = daysum + 366
        else:
          daysum = daysum + 365
      day1pass = day_of_year(int(day1), int(month1), int(year1))
      day2pass = day_of_year(int(day2), int(month2), int(year2))
      result = daysum - day1pass - (day_in_year(int(year2)) - day2pass)
      return result+1


# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 731
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 76
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 367 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 366 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 367 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 365 (ทั้งปี 2023)
# Out:
# 731
# 76
# 367
# 366
# 366
# 365

# %% [markdown]
# Exercise 5.3 จากโปรแกรม 5.2 ให้เขียนฟังก์ชัน date_diff  เพิ่มเติม โดยให้มีการตรวจสอบ
# วันที่ต้องเป็นวันที่ถูกต้องของเดือนนั้นๆ
# เดือนต้องอยู่ระหว่าง 1-12
# เดือนกุมภาพันธ์ของปีที่มี Leap Year เท่านั้นที่จะมี 29 วันได้
# หากข้อมูล Input ผิดพลาด ให้ Return -1

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

def day_of_year(day, month, year):
    sumday = sum(days_in_month[:month-1]) + day
    if is_leap(year) and month > 2:
        sumday += 1
    return sumday

def day_in_year(year):
    return 366 if is_leap(year) else 365

def is_valid_date(day, month, year):
    if month < 1 or month > 12:
        return False
    if day < 1 or day > days_in_month[month-1]:
        return False
    if month == 2 and is_leap(year) and day > 29:
        return False
    if month == 2 and not is_leap(year) and day > 28:
        return False
    return True

def date_diff(date1, date2):
    try:
        day1, month1, year1 = map(int, date1.split('-'))
        day2, month2, year2 = map(int, date2.split('-'))
    except ValueError:
        return -1

    if not is_valid_date(day1, month1, year1) or not is_valid_date(day2, month2, year2):
        return -1

    if year1 == year2:
        day1pass = day_of_year(day1, month1, year1)
        day2pass = day_of_year(day2, month2, year2)
        return day2pass - day1pass
    else:
        if year1 > year2 or (year1 == year2 and day_of_year(day1, month1, year1) > day_of_year(day2, month2, year2)):
            day1, month1, year1, day2, month2, year2 = day2, month2, year2, day1, month1, year1

        daysum = day_in_year(year1) - day_of_year(day1, month1, year1) + 1
        daysum += day_of_year(day2, month2, year2)

        for year in range(year1 + 1, year2):
            daysum += day_in_year(year)

        return daysum

# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 730
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 75
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 366 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 365 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 366 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 364 (ทั้งปี 2023)

# ทดสอบกรณีข้อมูลไม่ถูกต้อง
print()
print(date_diff("31-4-2023", "1-5-2023"))  # ควรได้ -1 (เดือนเมษายนมี 30 วัน)
print(date_diff("29-2-2023", "1-3-2023"))  # ควรได้ -1 (ปี 2023 ไม่ใช่ leap year)
print(date_diff("1-13-2023", "1-1-2024"))  # ควรได้ -1 (เดือนไม่ถูกต้อง)
print(date_diff("abc", "1-1-2024"))  # ควรได้ -1 (รูปแบบวันที่ไม่ถูกต้อง)
# Out:
# 731
# 76
# 367
# 366
# 366
# 364
#
# -1
# -1
# -1
# -1

# %% [markdown]
# 1.	ปลาหมอคางดำเพศเมีย 1 ตัว เมื่ออายุครบ 2 เดือน จะสามารถสืบพันธ์ได้ โดยระยะเวลาตั้งท้องจนถึง
# วางไข่ของตัวเมียจะใช้เวลา 21 วัน และฟักในปากเพศผู้อีก 7 วัน (สามารถรวมเป็น 1 เดือนได้) โดยออกไข่ครั้งละ 300 ฟอง กำหนดให้ไข่ฟักเป็นเพศผู้และเพศเมียอย่างละครึ่ง และเมื่อวางไข่แล้วจะสามารถสืบพันธ์ต่อได้ทันที กำหนดให้ปลามีอายุ 5 ปี และปลาทั้งหมดจะตาย p% ทุก 1 เดือน จงหาว่าปลาหมอคางดำหลุดจากฟาร์ม n ตัวเป็นเพศผู้และเพศเมียอย่างละครึ่ง จงเขียนโปรแกรมรับค่า n และ p ให้แสดงผลจำนวนปลาทุก 3 เดือน เป็นเวลา 10 ปี ให้เขียนเป็นฟังก์ชัน ชื่อ simulate_fish_population()

# %%
import math
def simulate_fish_population(n, p ,month=3):
  deadtime = 5*12
  round = month / 3
  monthcount = 0
  egg_fish = 0
  baby_fish = 0
  big_fish = 0
  fish_count_month = []
  for i in range(int(round)):
    if monthcount >= deadtime: #เกิน 5 ปี จะมีปลาตาย
      n -= fish_count_month[0]
      fish_count_month.pop(0)
    egg_fish = (n/2) * 300
    monthcount +=1

    if monthcount >= deadtime: #เกิน 5 ปี จะมีปลาตาย
      n -= fish_count_month[0]
      fish_count_month.pop(0)
    fish_count_month.append(n) # เก็บจำนวนปลาเต็มวัยเดือนนั้นๆ
    baby_fish += egg_fish - (egg_fish * p/100) #ปลาตาย p %
    egg_fish -= (n/2) * 300
    egg_fish += (n/2) * 300
    monthcount +=1

    if monthcount >= deadtime: #เกิน 5 ปี จะมีปลาตาย
      n -= fish_count_month[0]
      fish_count_month.pop(0)
    fish_count_month.append(n) # เก็บจำนวนปลาเต็มวัยเดือนนั้นๆ
    big_fish = baby_fish - (baby_fish * p/100) #ปลาตาย p %
    monthcount +=1
    print(f'เดือนที่ : {monthcount}, ไข่ปลา : {int(egg_fish)} ใบ  ลูกปลา : {int(baby_fish)} + ปลาเต็มวัย : {int(big_fish)} + {int(n)} = {int(baby_fish+big_fish+n)} ตัว')
    big_fish += n
    n = big_fish
    fish_count_month.append(n) # เก็บจำนวนปลาเต็มวัยเดือนนั้นๆ

  return egg_fish ,baby_fish ,big_fish

month = 10 * 12
# Run simulation
n = 2  # Initial number of fish
p = 10  # Monthly mortality rate

simulate_fish_population(n, p, month)

# ถ้าเริ่มต้นด้วยปลา 2 ตัว ตายเดือนละ 10%
# เดือนที่ 1 ไข่ 300 ไบ
# เดือนที่ 2 ไข่ 300 ใบ + ลูกปลา 270 ตัว
# เดือนที่ 3 ไข่ 300 ใบ + ลูกปลา 270 ตัว + ปลาโตเต็มวัย 243 ตัว + 2 = 515 ตัว
# Out:
# เดือนที่ : 3, ไข่ปลา : 300 ใบ  ลูกปลา : 270 + ปลาเต็มวัย : 243 + 2 = 515 ตัว
# เดือนที่ : 6, ไข่ปลา : 36750 ใบ  ลูกปลา : 33345 + ปลาเต็มวัย : 30010 + 245 = 63600 ตัว
# เดือนที่ : 9, ไข่ปลา : 4538325 ใบ  ลูกปลา : 4117837 + ปลาเต็มวัย : 3706053 + 30255 = 7854146 ตัว
# เดือนที่ : 12, ไข่ปลา : 560446387 ใบ  ลูกปลา : 508519586 + ปลาเต็มวัย : 457667627 + 3736309 = 969923523 ตัว
# เดือนที่ : 15, ไข่ปลา : 69210590531 ใบ  ลูกปลา : 62798051064 + ปลาเต็มวัย : 56518245957 + 461403936 = 119777700959 ตัว
# เดือนที่ : 18, ไข่ปลา : 8546947484221 ใบ  ลูกปลา : 7755050786864 + ปลาเต็มวัย : 6979545708177 + 56979649894 = 14791576144936 ตัว
# เดือนที่ : 21, ไข่ปลา : 1055478803710870 ใบ  ลูกปลา : 957685974126647 + ปลาเต็มวัย : 861917376713982 + 7036525358072 = 1826639876198702 ตัว
# เดือนที่ : 24, ไข่ปลา : 130343085310808256 ใบ  ลูกปลา : 118266462753854064 + ปลาเต็มวัย : 106439816478468656 + 868953902072055 = 225575233134394784 ตัว
# เดือนที่ : 27, ไข่ปลา : 16096315557081106432 ใบ  ลูกปลา : 14604950464126849024 + ปลาเต็มวัย : 13144455417714163712 + 107308770380540704 = 27856714652221554688 ตัว
# เดือนที่ : 30, ไข่ปลา : 1987764628214205644800 ใบ  ลูกปลา : 1803593115856911728640 + ปลาเต็มวัย : 1623233804271220686848 + 13251764188094703616 = 3440078684316227338240 ตัว
# เดือนที่ : 33, ไข่ปลา : 245472835268897316798464 ใบ  ลูกปลา : 222729144857864517451776 + ปลาเต็มวัย : 200456230372078058995712 + 1636485568459315347456 = 424821860798401947369472 ตัว
# เดือนที่ : 36, ไข่ปลา : 30313907391080604555542528 ใบ  ลูกปลา : 27505245796830411784978432 + ปลาเต็มวัย : 24754721217147369317990400 + 202092715940537362808832 = 52462059729918318667104256 ตัว
# เดือนที่ : 39, ไข่ปลา : 3743522089963186126808154112 ใบ  ลูกปลา : 3396675126763698296138498048 + ปลาเต็มวัย : 3057007614087328796378136576 + 24956813933087906882125824 = 6478639554784114728815820800 ตัว
# เดือนที่ : 42, ไข่ปลา : 462294664203062451707458879488 ใบ  ลูกปลา : 419461872909519865030530564096 + ปลาเต็มวัย : 377515685618567906674975178752 + 3081964428020416432677322752 = 800059522956108062793857499136 ตัว
# เดือนที่ : 45, ไข่ปลา : 57089647506988247678897549737984 ใบ  ลูกปลา : 51800144629198944436740687921152 + ปลาเต็มวัย : 46620130166279050893786544603136 + 380597650046588338500815290368 = 98800872445524592535489814200320 ตัว
# เดือนที่ : 48, ไข่ปลา : 7050109172448845395358119484194816 ใบ  ลูกปลา : 6396898399833159726400014334820352 + ปลาเต็มวัย : 5757208559849843407883561519284224 + 47000727816325639091549871538176 = 12201107687499327494352831552421888 ตัว
# เดือนที่ : 51, ไข่ปลา : 870631393149925361189578365804216320 ใบ  ลูกปลา : 789965152234765985949942048165462016 + ปลาเต็มวัย : 710968637011289343082762066445991936 + 5804209287666168920874321824448512 = 1506737998533721458754247279803105280 ตัว
# เดือนที่ : 54, ไข่ปลา : 107515926944843328889639224588172787712 ใบ  ลูกปลา : 97554299402593760717489251906303819776 + ปลาเต็มวัย : 87798869462334392201526699307105779712 + 716772846298955472804305231637643264 = 186069941711227115622943933339191476224 ตัว
# เดือนที่ : 57, ไข่ปลา : 13277346346295002404681701229875590856704 ใบ  ลูกปลา : 12047166011068095237354460452973992476672 + ปลาเต็มวัย : 10842449409961285955404178330602428170240 + 88515642308633354905454681432887656448 = 22978131063338014509885161602052146593792 ตัว
# เดือนที่ : 60, ไข่ปลา : 1639644757840488031115000247658707383484416 ใบ  ลูกปลา : 1487727448067507051957900761823023833546752 + ปลาเต็มวัย : 1338954703260756253916607739237200832757760 + 10930965052269919272530701149078154117120 = 2837613116380532739158859717128374588538880 ตัว
# เดือนที่ : 63, ไข่ปลา : 202482850246953936641096495058971168939704320 ใบ  ลูกปลา : 183722292670326040434909441853199945411067904 + ปลาเต็มวัย : 165350063403293428468602246241446191515566080 + 1349885668313026151428473687322953842163712 = 350422241741932491186377539015155731709034496 ตัว
# เดือนที่ : 66, ไข่ปลา : 25004992360740966741210426917385654415711535104 ใบ  ลูกปลา : 22688215417337197803006971472757113421391986688 + ปลาเต็มวัย : 20419393875603477769176154279835521779912146944 + 166699949071606450751468097161955786297966592 = 43274309242012279448019312136163619197423714304 ตัว
# เดือนที่ : 69, ไข่ปลา : 3087914073701262941424380024580687886598115688448 ใบ  ลูกปลา : 2801810881748473919622804287015265019365844582400 + ปลาเต็มวัย : 2521629793573626365401247029100375125851249836032 + 20586093824675084180313541119865308769438138368 = 5344026769146776003029664971350206202338135244800 ตัว
# เดือนที่ : 72, ไข่ปลา : 381332383109745195035312678299766081943364150755328 ใบ  ลูกปลา : 346000955680519116934645138182446715096160318521344 + ปลาเต็มวัย : 311400860112467196933505650708477837937750159917056 + 2542215887398301434369753367481487616660249509888 = 659944031680384616276076203233686221000038789677056 ตัว
# เดือนที่ : 75, ไข่ปลา : 47091461399979824070447162392113505320702357998141440 ใบ  ลูกปลา : 42728316215662363106486083914687379085390638007451648 + ปลาเต็มวัย : 38455484594096127859219872151151339499897222430982144 + 313943075999865499341431065051239505903878471155712 = 81497743885758349901984157942867835628644378775388160 ตัว
# เดือนที่ : 78, ไข่ปลา : 5815414150514398976368868069366496972229144517038571520 ใบ  ลูกปลา : 5276601051678620888879621099819531526107883626718822400 + ปลาเต็มวัย : 4748940946510758799991658989837578373497095264046940160 + 38769427670095992112410057167843948158481981889314816 = 10064311425859475069538812085763652312012213143696572416 ตัว
# เดือนที่ : 81, ไข่ปลา : 718156556127128268656343287002018918649486119162238468096 ใบ  ลูกปลา : 651617501566094067307428769526399661412540051944781119488 + ปลาเต็มวัย : 586455751409484643154228706221710365946506146243770580992 + 4787710374180854861223924827821047712653544380514172928 = 1242860963349759515641655830118915409419007057530907000832 ตัว
# เดือนที่ : 84, ไข่ปลา : 88686519267549828400506658354188932968829187162099635191808 ใบ  ลูกปลา : 80469484842360929940877225676557012228781183816202423631872 + ปลาเต็มวัย : 72422536358124835831752243182370153929117151802164105969664 + 591243461783665535446512992352762394630366508118788014080 = 153483264662269414495404797021552325754116098137681525997568 ตัว
# เดือนที่ : 87, ไข่ปลา : 10952066972986275738381227900444667419193640501047391674171392 ใบ  ลูกปลา : 9937329760530009154695994372109440171649496970909430996533248 + ปลาเต็มวัย : 8943596784477008524675933476090472366141741163717515173429248 + 73013779819908506855272769875618455061053186969840608346112 = 18953940324826926108174592423218349997477277367327521507377152 ตัว
# เดือนที่ : 90, ไข่ปลา : 1352491584644537588693715874257052667739318081846557940874477568 ใบ  ลูกปลา : 1227179755940613954871552928927399183069856489931816652062588928 + ปลาเต็มวัย : 1104461780346552541115627169398372787216810431985097241157173248 + 9016610564296916953478598051108909825827780396418090510843904 = 2340658146851463481448547946262955170910221235889098530102444032 ตัว
# เดือนที่ : 93, ไข่ปลา : 167021758636627430082675480598510586828818336430804546447927672832 ใบ  ลูกปลา : 151546762528905293466008512280164325624937349970891281735746584576 + ปลาเต็มวัย : 136392086276014754765797182134369216558860685589590827764203651072 + 1113478390910849526576995017335555987840364745957281878039855104 = 289052327195830916940591679399969899595001829707654024362104717312 ตัว
# เดือนที่ : 96, ไข่ปลา : 20625834700038838750846130819903711078682377974566635236989899636736 ใบ  ลูกปลา : 18714797992563860627554439717164659445114641066907217959127101734912 + ปลาเต็มวัย : 16843318193307474265483460420079275852488523219921733737679406759936 + 137505564666925600090556969825358882711107156276234428131437445120 = 35695621750538259347311173439641406308625362593539298714686832246784 ตัว
# เดือนที่ : 99, ไข่ปลา : 2547123563696159658305742395687053205469281358847430900566467176038400 ใบ  ลูกปลา : 2311126005319107663849470666222012074169889747938657125916891936718848 + ปลาเต็มวัย : 2080013404787196974089300642894253784670252130660250594262158852227072 + 16980823757974398719756733722476746863510721526632080755559730511872 = 4408120233864278907952847852930108017014351491798791957954567054819328 ตัว
# เดือนที่ : 102, ไข่ปลา : 314549134281775706537948609262769550085180614533039611849259856101900288 ใบ  ลูกปลา : 285405346858917233280283095201259256149907360920602777544698643798294528 + ปลาเต็มวัย : 256864812173025505048269054910288983788206137947553112210263588430938112 + 2096994228545171244103377186708095942844461743860134832037675118100480 = 544367153260487939456318574183089073868724990043045105152412789927575552 ตัว
# เดือนที่ : 105, ไข่ปลา : 38844270960235600532021017999345691236441108799278022803195411833112494080 ใบ  ลูกปลา : 35245249211070959036175346602740354990558736738137957947011170860231819264 + ปลาเต็มวัย : 31720724289963862504847638403798243107923920743557520542074509327805186048 + 258961806401570657136178171273386350251712760312548451808062236254011392 = 67224935307436398279101469333658974414655373974434867540050579248824451072 ตัว
# เดือนที่ : 108, ไข่ปลา : 4796952914454815145740913634009462780991343646939899338877968811532822249472 ใบ  ลูกปลา : 4352502872220404842542487379755823564081502831932237290251871968693959262208 + ปลาเต็มวัย : 3917252584998364036900629789982186099280934080506493056786086015265996275712 + 31979686096365432965824387344237855588307214028630493490683963924558118912 = 8301735143315135015444335920390493068559159525725999443992451727856379101184 ตัว
# เดือนที่ : 111, ไข่ปลา : 592384840664209358813720678160211769307590900588153660751975610463908104503296 ใบ  ลูกปลา : 537498859470008843201496322610253061143749399836431516180178661701022472208384 + ปลาเต็มวัย : 483748973523007969165750173606765518497931850836229020704259955740794370916352 + 3949232271094729369432826411139531733496610523212460892639082867766002188288 = 1025197065264111446123865689218236716628433366896698147705999570233409144881152 ตัว
# เดือนที่ : 114, ไข่ปลา : 73154730869115412446978859162328362145415411763602998872965339128988673188560896 ใบ  ลูกปลา : 66376756641673880600840257664612818219319719100184925933522338529124032222068736 + ปลาเต็มวัย : 59739080977506489907948940184221868949437055098405625367792719662483847642087424 + 487698205794102705766404199183361290170257876894673192946812510631128131960832 = 126603535824974496251619404544902638628495587878392294252563989572357094876643328 ตัว
# เดือนที่ : 117, ไข่ปลา : 9034016877495088766998955301099125332163439071936406405423004037815176751612952576 ใบ  ลูกปลา : 8196991946387254571273316709688444521343425279738236314416951016736028641437155328 + ปลาเต็มวัย : 7377292751748528777146651699336602635871394164019029262510950633305269763498311680 + 60226779183300589322706229740993145929668947860599288595267800905955249076830208 = 15634511477319082805635539201776283300525690792160717437400893895044307670169288704 ตัว
# เดือนที่ : 120, ไข่ปลา : 1115627929639774349734106709203394944212153946696802531405455227543674899000163565568 ใบ  ลูกปลา : 1012262128622184174049960021744105858379009617535295882465826929750643621934716157952 + ปลาเต็มวัย : 911035915759965735077006685849183436807496586166061755309528698743121274858356342784 + 7437519530931829076860555840545332362526486981785939674144706082701169063219953664 = 1930735563913081909230988933170705824967909648963925663335135265068222742857319972864 ตัว
# (1.1156279296397743e+84, 1.0122621286221842e+84, 9.184734352908975e+83)

# %% [markdown]
# 2.	ให้เขียน function find_mismatch ซึ่งรับ string มา 2 ค่า โดยจะส่งค่ากลับดังนี้
# - 0 เมื่อ string ทั้ง 2 ตัว เหมือนกัน โดยไม่สนใจ case
# - 1 เมื่อ string 1 จะเหมือน string 2 โดยการลบและ/หรือเพิ่มตัวอักษรเพียง 1 ตัว
# - 2 เมื่อ string ไม่เข้าเกณฑ์ 0 หรือ 1
#
#
# | String  1| 	String2	|ผลลัพธ์|
# |----------|----------|------|
# |Python|	Java	|2|
# |book	 |  boot	|1|
# |fan	 |  fun	  |1|
# |sin	 | sink	  |1 เพราะเพิ่ม k ใน str2 แล้วจะเหมือนกัน
# |Dog	 | dog	  |0
# |poke	 | spoke	|1 เพิ่ม s ใน str2 แล้วเหมือนกัน
# |poker |	poke	|1 ตัด r ใน str1 ออกแล้วเหมือนกัน

# %%
# str1 = 'Dog'
# str2 = 'dog'

def Convert(str1, str2):
    str1 = list(str1.lower())
    str2 = list(str2.lower())
    return str1, str2

def find_mismatch(str1, str2):
    x = 0
    str1, str2 = Convert(str1, str2)
    i = 0
    while i < len(str1):
        j = 0
        while j < len(str2):
            # print(f'{str1} - {str2}')
            # print(f'{str1[i]} - {str2[j]}')
            if str1[i] == str2[j]:
                str1.pop(i)
                str2.pop(j)
                if i > 0:
                    i -= 1
                break
            else:
                j += 1
        else:
            i += 1
    if len(str1)>len(str2):
      x =  len(str1) - len(str2)
    elif len(str1)<len(str2):
      x =  len(str2) - len(str1)
    else :
      if len(str1) == 0 and len(str2) == 0 :
        return 0#,str1,str2,x

    if x >= 0 and x < 2:
      return 1#,str1,str2,x
    else :
      return 2#,str1,str2,x



print(find_mismatch('Python', 'Java'))
print(find_mismatch('book', 'boot'))
print(find_mismatch('fan', 'fun'))
print(find_mismatch('sin', 'sink'))
print(find_mismatch('Dog', 'dog'))
print(find_mismatch('spoke', 'poke'))
print(find_mismatch('poker', 'poke'))
# Out:
# 2
# 1
# 1
# 1
# 0
# 1
# 1

# %% [markdown]
# 3.	จากข้อ 1 ให้เขียนฟังก์ชันชื่อ spelling_correction โดยรับ 2 argument ตัวแรกเป็นประโยค (string) และตัวที่ 2 เป็น list ของคำ (correct_spells) โดยฟังก์ชันนี้มีหน้าที่ตรวจสอบแต่ละ word ใน input string กับคำที่อยู่ใน correct_spells โดยค่าที่คืนกลับมาจะมีดังนี้ (พยายามเรียกใช้ฟังก์ชันในข้อ 1)
# -	ถ้าคำที่อยู่ในประโยค ตรงกับคำที่อยู่ใน correct_spells ทุกอย่าง ก็จะ copy ไปที่ output string
# -	ถ้าคำที่อยู่ในประโยค ต่างจากคำที่อยู่ใน correct_spells โดยต่างกัน 1 ตัวอักษร โดยการเปลี่ยน การเพิ่ม หรือการลบ 1 ตัวอักษร คำที่อยู่ในประโยคจะถูกเปลี่ยนโดยคำที่อยู่ใน correct_spells และนำไปใส่ output string
# -	ถ้าคำที่ไม่พบในเงื่อนไขข้างต้นให้นำคำนั้นไปใส่ output string ได้เลย
# -	คำที่ประกอบด้วย 1 หรือ 2 ตัวอักษรจะไม่ตรวจสอบ ให้นำคำนั้นไปใส่ output string ได้เลย
# -	ถ้ามี 2 คำใน correct_spells ที่ตรงตามเงื่อนไข ให้ใช้คำแรก
# -	ไม่สนใจตัวใหญ่ ตัวเล็ก
# -	Input string จะมีได้เพียงอักษรภาษาอังกฤษเท่านั้น
# -	ในแต่ละคำจะคั่นด้วย 1 space ถ้ามี space มากกว่านั้นให้ตัดออก และตัด space จากหัวท้ายประโยค
#
# |ประโยค	|correct_spells	|output string |
# |-------|---------------|-------------|
# |Thes is the Firs cas	|[‘that’,’first’,’case’,’car’]|	thes is the first car|
# |programming is fan and easy	|[‘programming’,’this’,’fun’,’easy’,book’]	|programming is fun and easy|
# |Thes is vary essy	|[‘this’,’is’,’very’,’easy’]	|this is very easy|
# |Wee ipve Pythen	|[‘we’,’live’,’ln’,’Python’]	|we live python|

# %%
x1 = 'Thes is the Firs cas'
sent1 = ['that','first','case','car']
x2 = 'programming is fan and easy'
sent2 = ['programming','this','fun','easy','book']
x3 = 'Thes is vary essy'
sent3 = ['this','is','very','easy']
x4 = 'Wee ipve Pythen'
sent4 = ['we','live','ln','Python']

def spelling_correction(input_string, correct_spells):
  pass

# %% [markdown]
# 4. ให้เขียนฟังก์ชัน find_word_horizontal ซึ่งจะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตามแถวของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบ จะส่งคืน row index และ column index ของตัวอักษรแรก ถ้าไม่พบจะส่งคืน None
#
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','c','a','t'],
#             ['t',' e','t','k']]
# 	word='cat'
# 	find_word_horizontal(crosswords,word)
# ```
#
# Output
#    [2,1]

# %%
crosswords=[['s','d','o','g'],
            ['c','u','c','m'],
            ['a','c','a','t'],
            ['t',' e','t','k']]
word='cat'

def find_word_horizontal(crosswords, word):
    pass
find_word_horizontal(crosswords,word)

# %% [markdown]
# 5. ให้เขียนฟังก์ชัน find_word_vertical ซึ่งจะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตามคอลัมน์ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบ จะส่งคืน row index และ column index ของตัวอักษรแรก ถ้าไม่พบจะส่งคืน None
#
# ตัวอย่าง
# ```
# 	crosswords=[['s','d','o','g'],
#               ['c','u','c','m'],
#               ['a','c','a','t'],
#               ['t',' e','t','k']]
# 	word='cat'
# 	find_word_vertical(crosswords,word)
# ```
#
# Output
#    [1,0]

# %%
def find_word_vertical(crosswords, word):
    pass

# %% [markdown]
# 6.	ให้เขียนฟังก์ชัน capitalize_word_in_crossword จะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตาม row และ column ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบจะเปลี่ยนเป็นตัวใหญ่และ และส่งคืน list ที่แก้ไขแล้ว แต่ถ้าไม่เจอจะส่ง list เดิมกลับมา ให้ใช้ฟังก์ชันตามข้อ 3 และ 4 ช่วย
#
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','x','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# ```
# จะส่งค่ากลับ
# ```
#  [['s','d','o','g'],
#   ['C','u','c','m'],
#   ['A','x','a','t'],
#   ['T','e','t','k']]
# ```
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','c','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# จะส่งค่ากลับ
# [['s','d','o','g'],
#  ['c','u','c','m'],
#  ['a','C','A','T'],
#  ['t','e','t','k']]
# ```

# %%
def capitalize_word_in_crossword(crosswords, word):
    pass
